# %% [markdown]
# Import pandas and matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read Basic-2.xlsx

# %%
df = pd.read_excel('Basic-2.xlsx')
df.head()
# Out:
#     c1   c2   c3   c4   c5    c6          c7  c8   c9  c10   c11  \
# 0  1.0  5.0  NaN  NaN  NaN  40.0         NaN NaN  2.0  NaN  11.0
# 1  2.0  4.5  5.8  NaN  NaN  35.0    ret_allw NaN  NaN  yes  11.0
# 2  NaN  NaN  NaN  NaN  NaN  38.0  empl_contr NaN  5.0  NaN  11.0
# 3  3.0  3.7  4.0  5.0   tc   NaN         NaN NaN  NaN  yes   NaN
# 4  3.0  4.5  4.5  5.0  NaN  40.0         NaN NaN  NaN  NaN  12.0
#
#              c12  c13   c14  c15   c16   c17
# 0        average  NaN   NaN  yes   NaN  good
# 1  below average  NaN  full  NaN  full  good
# 2       generous  yes  half  yes  half  good
# 3            NaN  NaN   NaN  yes   NaN  good
# 4        average  NaN  half  yes  half  good

# %% [markdown]
# Show how many times 'no' showed up in  c13 column

# %%
no_times = (df['c13'] == 'no').sum()
no_times
# Out:
# 5

# %% [markdown]
# Sort the rows according to the first and then sixth column, where ascending in the first and descending in the sixth column. Display only first 6 columns.

# %%
sorted_rows = df.sort_values(by=['c1', 'c6'], ascending=[True, False]).iloc[:, :6]
sorted_rows
# Out:
#      c1   c2   c3   c4    c5    c6
# 0   1.0  5.0  NaN  NaN   NaN  40.0
# 9   1.0  5.7  NaN  NaN  none  40.0
# 17  1.0  2.1  NaN  NaN    tc  40.0
# 36  1.0  2.0  NaN  NaN    tc  40.0
# 18  1.0  2.0  NaN  NaN  none  38.0
# 24  1.0  6.0  NaN  NaN   NaN  38.0
# 37  1.0  2.8  NaN  NaN  none  38.0
# 14  1.0  3.0  NaN  NaN  none  36.0
# 16  1.0  2.8  NaN  NaN   NaN  35.0
# 12  2.0  3.5  4.0  NaN  none  40.0
# 21  2.0  2.5  3.0  NaN   NaN  40.0
# 23  2.0  4.5  4.0  NaN   NaN  40.0
# 33  2.0  4.0  5.0  NaN  none  40.0
# 35  2.0  2.0  2.0  NaN  none  40.0
# 39  2.0  4.5  4.0  NaN  none  40.0
# 8   2.0  3.0  7.0  NaN   NaN  38.0
# 11  2.0  6.4  6.4  NaN   NaN  38.0
# 20  2.0  4.3  4.4  NaN   NaN  38.0
# 32  2.0  2.5  2.5  NaN   NaN  38.0
# 15  2.0  4.5  4.0  NaN  none  37.0
# 28  2.0  5.0  4.0  NaN  none  37.0
# 1   2.0  4.5  5.8  NaN   NaN  35.0
# 5   2.0  2.0  2.5  NaN   NaN  35.0
# 19  2.0  4.0  5.0  NaN   tcf  35.0
# 27  2.0  3.0  3.0  NaN  none  33.0
# 26  2.0  4.5  4.5  NaN   tcf   NaN
# 4   3.0  4.5  4.5  5.0   NaN  40.0
# 7   3.0  6.9  4.8  2.3   NaN  40.0
# 25  3.0  2.0  2.0  2.0  none  40.0
# 30  3.0  4.5  4.5  5.0  none  40.0
# 31  3.0  3.0  2.0  2.5    tc  40.0
# 34  3.0  2.0  2.5  2.1    tc  40.0
# 13  3.0  3.5  4.0  5.1   tcf  37.0
# 38  3.0  2.0  2.5  2.0   NaN  37.0
# 10  3.0  3.5  4.0  4.6  none  36.0
# 29  3.0  2.0  2.5  NaN   NaN  35.0
# 22  3.0  3.5  4.0  4.6   tcf  27.0
# 3   3.0  3.7  4.0  5.0    tc   NaN
# 6   3.0  4.0  5.0  5.0    tc   NaN
# 2   NaN  NaN  NaN  NaN   NaN  38.0

# %% [markdown]
# In columns c1, c6 and c11, convert every number to the nearest integer.
# In column c12, replace the space between two words by underscore.

# %%
df.fillna(0, inplace=True)

print("After filling missing values with 0:")
print(df)

df[['c1', 'c6', 'c11']] = df[['c1', 'c6', 'c11']].applymap(round)

print("\nAfter rounding values in c1, c6, and c11:")
print(df)

df['c12'] = df['c12'].str.replace(' ', '_')

print("\nAfter replacing spaces in column c12:")
print(df)
# Out:
# After filling missing values with 0:
#      c1   c2   c3   c4    c5    c6          c7    c8    c9  c10   c11  \
# 0   1.0  5.0  0.0  0.0     0  40.0           0   0.0   2.0    0  11.0
# 1   2.0  4.5  5.8  0.0     0  35.0    ret_allw   0.0   0.0  yes  11.0
# 2   0.0  0.0  0.0  0.0     0  38.0  empl_contr   0.0   5.0    0  11.0
# 3   3.0  3.7  4.0  5.0    tc   0.0           0   0.0   0.0  yes   0.0
# 4   3.0  4.5  4.5  5.0     0  40.0           0   0.0   0.0    0  12.0
# 5   2.0  2.0  2.5  0.0     0  35.0           0   0.0   6.0  yes  12.0
# 6   3.0  4.0  5.0  5.0    tc   0.0  empl_contr   0.0   0.0    0  12.0
# 7   3.0  6.9  4.8  2.3     0  40.0           0   0.0   3.0    0  12.0
# 8   2.0  3.0  7.0  0.0     0  38.0           0  12.0  25.0  yes  11.0
# 9   1.0  5.7  0.0  0.0  none  40.0  empl_contr   0.0   4.0    0  11.0
# 10  3.0  3.5  4.0  4.6  none  36.0           0   0.0   3.0    0  13.0
# 11  2.0  6.4  6.4  0.0     0  38.0           0   0.0   4.0    0  15.0
# 12  2.0  3.5  4.0  0.0  none  40.0           0   0.0   2.0   no  10.0
# 13  3.0  3.5  4.0  5.1   tcf  37.0           0   0.0   4.0    0  13.0
# 14  1.0  3.0  0.0  0.0  none  36.0           0   0.0  10.0   no  11.0
# 15  2.0  4.5  4.0  0.0  none  37.0  empl_contr   0.0   0.0    0  11.0
# 16  1.0  2.8  0.0  0.0     0  35.0           0   0.0   2.0    0  12.0
# 17  1.0  2.1  0.0  0.0    tc  40.0    ret_allw   2.0   3.0   no   9.0
# 18  1.0  2.0  0.0  0.0  none  38.0        none   0.0   0.0  yes  11.0
# 19  2.0  4.0  5.0  0.0   tcf  35.0           0  13.0   5.0    0  15.0
# 20  2.0  4.3  4.4  0.0     0  38.0           0   0.0   4.0    0  12.0
# 21  2.0  2.5  3.0  0.0     0  40.0        none   0.0   0.0    0  11.0
# 22  3.0  3.5  4.0  4.6   tcf  27.0           0   0.0   0.0    0   0.0
# 23  2.0  4.5  4.0  0.0     0  40.0           0   0.0   4.0    0  10.0
# 24  1.0  6.0  0.0  0.0     0  38.0           0   8.0   3.0    0   9.0
# 25  3.0  2.0  2.0  2.0  none  40.0        none   0.0   0.0    0  10.0
# 26  2.0  4.5  4.5  0.0   tcf   0.0           0   0.0   0.0  yes  10.0
# 27  2.0  3.0  3.0  0.0  none  33.0           0   0.0   0.0  yes  12.0
# 28  2.0  5.0  4.0  0.0  none  37.0           0   0.0   5.0   no  11.0
# 29  3.0  2.0  2.5  0.0     0  35.0        none   0.0   0.0    0  10.0
# 30  3.0  4.5  4.5  5.0  none  40.0           0   0.0   0.0   no  11.0
# 31  3.0  3.0  2.0  2.5    tc  40.0        none   0.0   5.0   no  10.0
# 32  2.0  2.5  2.5  0.0     0  38.0  empl_contr   0.0   0.0    0  10.0
# 33  2.0  4.0  5.0  0.0  none  40.0        none   0.0   3.0   no  10.0
# 34  3.0  2.0  2.5  2.1    tc  40.0        none   2.0   1.0   no  10.0
# 35  2.0  2.0  2.0  0.0  none  40.0        none   0.0   0.0   no  11.0
# 36  1.0  2.0  0.0  0.0    tc  40.0    ret_allw   4.0   0.0   no  11.0
# 37  1.0  2.8  0.0  0.0  none  38.0  empl_contr   2.0   3.0   no   9.0
# 38  3.0  2.0  2.5  2.0     0  37.0  empl_contr   0.0   0.0    0  10.0
# 39  2.0  4.5  4.0  0.0  none  40.0           0   0.0   4.0    0  12.0
#
#               c12  c13   c14  c15   c16   c17
# 0         average    0     0  yes     0  good
# 1   below average    0  full    0  full  good
# 2        generous  yes  half  yes  half  good
# 3               0    0     0  yes     0  good
# 4         average    0  half  yes  half  good
# 5         average    0     0    0     0  good
# 6        generous  yes  none  yes  half  good
# 7   below average    0     0    0     0  good
# 8   below average  yes  half  yes     0  good
# 9        generous  yes  full    0     0  good
# 10       generous    0     0  yes  full  good
# 11              0    0  full    0     0  good
# 12  below average   no  half    0  half   bad
# 13       generous    0  full  yes  full  good
# 14       generous    0     0    0     0  good
# 15        average    0  full  yes     0  good
# 16  below average    0     0    0     0  good
# 17  below average  yes  half    0  none   bad
# 18        average   no  none   no  none   bad
# 19       generous    0     0    0     0  good
# 20       generous    0  full    0  full  good
# 21  below average    0     0    0     0   bad
# 22              0    0     0    0     0  good
# 23       generous    0  half    0  full  good
# 24       generous    0     0    0     0  good
# 25  below average    0  half  yes  full   bad
# 26  below average  yes  none    0  half  good
# 27       generous    0     0  yes  full  good
# 28  below average  yes  full  yes  full  good
# 29        average    0     0  yes  full   bad
# 30        average    0  half    0     0  good
# 31  below average  yes  half  yes  full   bad
# 32        average    0     0    0     0   bad
# 33  below average   no  none    0  none   bad
# 34  below average   no  half  yes  full   bad
# 35        average  yes  none  yes  full   bad
# 36       generous   no  none   no  none   bad
# 37  below average  yes  half    0  none   bad
# 38        average    0     0  yes  none   bad
# 39        average  yes  full  yes  half  good
#
# After rounding values in c1, c6, and c11:
#     c1   c2   c3   c4    c5  c6          c7    c8    c9  c10  c11  \
# 0    1  5.0  0.0  0.0     0  40           0   0.0   2.0    0   11
# 1    2  4.5  5.8  0.0     0  35    ret_allw   0.0   0.0  yes   11
# 2    0  0.0  0.0  0.0     0  38  empl_contr   0.0   5.0    0   11
# 3    3  3.7  4.0  5.0    tc   0           0   0.0   0.0  yes    0
# 4    3  4.5  4.5  5.0     0  40           0   0.0   0.0    0   12
# 5    2  2.0  2.5  0.0     0  35           0   0.0   6.0  yes   12
# 6    3  4.0  5.0  5.0    tc   0  empl_contr   0.0   0.0    0   12
# 7    3  6.9  4.8  2.3     0  40           0   0.0   3.0    0   12
# 8    2  3.0  7.0  0.0     0  38           0  12.0  25.0  yes   11
# 9    1  5.7  0.0  0.0  none  40  empl_contr   0.0   4.0    0   11
# 10   3  3.5  4.0  4.6  none  36           0   0.0   3.0    0   13
# 11   2  6.4  6.4  0.0     0  38           0   0.0   4.0    0   15
# 12   2  3.5  4.0  0.0  none  40           0   0.0   2.0   no   10
# 13   3  3.5  4.0  5.1   tcf  37           0   0.0   4.0    0   13
# 14   1  3.0  0.0  0.0  none  36           0   0.0  10.0   no   11
# 15   2  4.5  4.0  0.0  none  37  empl_contr   0.0   0.0    0   11
# 16   1  2.8  0.0  0.0     0  35           0   0.0   2.0    0   12
# 17   1  2.1  0.0  0.0    tc  40    ret_allw   2.0   3.0   no    9
# 18   1  2.0  0.0  0.0  none  38        none   0.0   0.0  yes   11
# 19   2  4.0  5.0  0.0   tcf  35           0  13.0   5.0    0   15
# 20   2  4.3  4.4  0.0     0  38           0   0.0   4.0    0   12
# 21   2  2.5  3.0  0.0     0  40        none   0.0   0.0    0   11
# 22   3  3.5  4.0  4.6   tcf  27           0   0.0   0.0    0    0
# 23   2  4.5  4.0  0.0     0  40           0   0.0   4.0    0   10
# 24   1  6.0  0.0  0.0     0  38           0   8.0   3.0    0    9
# 25   3  2.0  2.0  2.0  none  40        none   0.0   0.0    0   10
# 26   2  4.5  4.5  0.0   tcf   0           0   0.0   0.0  yes   10
# 27   2  3.0  3.0  0.0  none  33           0   0.0   0.0  yes   12
# 28   2  5.0  4.0  0.0  none  37           0   0.0   5.0   no   11
# 29   3  2.0  2.5  0.0     0  35        none   0.0   0.0    0   10
# 30   3  4.5  4.5  5.0  none  40           0   0.0   0.0   no   11
# 31   3  3.0  2.0  2.5    tc  40        none   0.0   5.0   no   10
# 32   2  2.5  2.5  0.0     0  38  empl_contr   0.0   0.0    0   10
# 33   2  4.0  5.0  0.0  none  40        none   0.0   3.0   no   10
# 34   3  2.0  2.5  2.1    tc  40        none   2.0   1.0   no   10
# 35   2  2.0  2.0  0.0  none  40        none   0.0   0.0   no   11
# 36   1  2.0  0.0  0.0    tc  40    ret_allw   4.0   0.0   no   11
# 37   1  2.8  0.0  0.0  none  38  empl_contr   2.0   3.0   no    9
# 38   3  2.0  2.5  2.0     0  37  empl_contr   0.0   0.0    0   10
# 39   2  4.5  4.0  0.0  none  40           0   0.0   4.0    0   12
#
#               c12  c13   c14  c15   c16   c17
# 0         average    0     0  yes     0  good
# 1   below average    0  full    0  full  good
# 2        generous  yes  half  yes  half  good
# 3               0    0     0  yes     0  good
# 4         average    0  half  yes  half  good
# 5         average    0     0    0     0  good
# 6        generous  yes  none  yes  half  good
# 7   below average    0     0    0     0  good
# 8   below average  yes  half  yes     0  good
# 9        generous  yes  full    0     0  good
# 10       generous    0     0  yes  full  good
# 11              0    0  full    0     0  good
# 12  below average   no  half    0  half   bad
# 13       generous    0  full  yes  full  good
# 14       generous    0     0    0     0  good
# 15        average    0  full  yes     0  good
# 16  below average    0     0    0     0  good
# 17  below average  yes  half    0  none   bad
# 18        average   no  none   no  none   bad
# 19       generous    0     0    0     0  good
# 20       generous    0  full    0  full  good
# 21  below average    0     0    0     0   bad
# 22              0    0     0    0     0  good
# 23       generous    0  half    0  full  good
# 24       generous    0     0    0     0  good
# 25  below average    0  half  yes  full   bad
# 26  below average  yes  none    0  half  good
# 27       generous    0     0  yes  full  good
# 28  below average  yes  full  yes  full  good
# 29        average    0     0  yes  full   bad
# 30        average    0  half    0     0  good
# 31  below average  yes  half  yes  full   bad
# 32        average    0     0    0     0   bad
# 33  below average   no  none    0  none   bad
# 34  below average   no  half  yes  full   bad
# 35        average  yes  none  yes  full   bad
# 36       generous   no  none   no  none   bad
# 37  below average  yes  half    0  none   bad
# 38        average    0     0  yes  none   bad
# 39        average  yes  full  yes  half  good
#
# After replacing spaces in column c12:
#     c1   c2   c3   c4    c5  c6          c7    c8    c9  c10  c11  \
# 0    1  5.0  0.0  0.0     0  40           0   0.0   2.0    0   11
# 1    2  4.5  5.8  0.0     0  35    ret_allw   0.0   0.0  yes   11
# 2    0  0.0  0.0  0.0     0  38  empl_contr   0.0   5.0    0   11
# 3    3  3.7  4.0  5.0    tc   0           0   0.0   0.0  yes    0
# 4    3  4.5  4.5  5.0     0  40           0   0.0   0.0    0   12
# 5    2  2.0  2.5  0.0     0  35           0   0.0   6.0  yes   12
# 6    3  4.0  5.0  5.0    tc   0  empl_contr   0.0   0.0    0   12
# 7    3  6.9  4.8  2.3     0  40           0   0.0   3.0    0   12
# 8    2  3.0  7.0  0.0     0  38           0  12.0  25.0  yes   11
# 9    1  5.7  0.0  0.0  none  40  empl_contr   0.0   4.0    0   11
# 10   3  3.5  4.0  4.6  none  36           0   0.0   3.0    0   13
# 11   2  6.4  6.4  0.0     0  38           0   0.0   4.0    0   15
# 12   2  3.5  4.0  0.0  none  40           0   0.0   2.0   no   10
# 13   3  3.5  4.0  5.1   tcf  37           0   0.0   4.0    0   13
# 14   1  3.0  0.0  0.0  none  36           0   0.0  10.0   no   11
# 15   2  4.5  4.0  0.0  none  37  empl_contr   0.0   0.0    0   11
# 16   1  2.8  0.0  0.0     0  35           0   0.0   2.0    0   12
# 17   1  2.1  0.0  0.0    tc  40    ret_allw   2.0   3.0   no    9
# 18   1  2.0  0.0  0.0  none  38        none   0.0   0.0  yes   11
# 19   2  4.0  5.0  0.0   tcf  35           0  13.0   5.0    0   15
# 20   2  4.3  4.4  0.0     0  38           0   0.0   4.0    0   12
# 21   2  2.5  3.0  0.0     0  40        none   0.0   0.0    0   11
# 22   3  3.5  4.0  4.6   tcf  27           0   0.0   0.0    0    0
# 23   2  4.5  4.0  0.0     0  40           0   0.0   4.0    0   10
# 24   1  6.0  0.0  0.0     0  38           0   8.0   3.0    0    9
# 25   3  2.0  2.0  2.0  none  40        none   0.0   0.0    0   10
# 26   2  4.5  4.5  0.0   tcf   0           0   0.0   0.0  yes   10
# 27   2  3.0  3.0  0.0  none  33           0   0.0   0.0  yes   12
# 28   2  5.0  4.0  0.0  none  37           0   0.0   5.0   no   11
# 29   3  2.0  2.5  0.0     0  35        none   0.0   0.0    0   10
# 30   3  4.5  4.5  5.0  none  40           0   0.0   0.0   no   11
# 31   3  3.0  2.0  2.5    tc  40        none   0.0   5.0   no   10
# 32   2  2.5  2.5  0.0     0  38  empl_contr   0.0   0.0    0   10
# 33   2  4.0  5.0  0.0  none  40        none   0.0   3.0   no   10
# 34   3  2.0  2.5  2.1    tc  40        none   2.0   1.0   no   10
# 35   2  2.0  2.0  0.0  none  40        none   0.0   0.0   no   11
# 36   1  2.0  0.0  0.0    tc  40    ret_allw   4.0   0.0   no   11
# 37   1  2.8  0.0  0.0  none  38  empl_contr   2.0   3.0   no    9
# 38   3  2.0  2.5  2.0     0  37  empl_contr   0.0   0.0    0   10
# 39   2  4.5  4.0  0.0  none  40           0   0.0   4.0    0   12
#
#               c12  c13   c14  c15   c16   c17
# 0         average    0     0  yes     0  good
# 1   below_average    0  full    0  full  good
# 2        generous  yes  half  yes  half  good
# 3             NaN    0     0  yes     0  good
# 4         average    0  half  yes  half  good
# 5         average    0     0    0     0  good
# 6        generous  yes  none  yes  half  good
# 7   below_average    0     0    0     0  good
# 8   below_average  yes  half  yes     0  good
# 9        generous  yes  full    0     0  good
# 10       generous    0     0  yes  full  good
# 11            NaN    0  full    0     0  good
# 12  below_average   no  half    0  half   bad
# 13       generous    0  full  yes  full  good
# 14       generous    0     0    0     0  good
# 15        average    0  full  yes     0  good
# 16  below_average    0     0    0     0  good
# 17  below_average  yes  half    0  none   bad
# 18        average   no  none   no  none   bad
# 19       generous    0     0    0     0  good
# 20       generous    0  full    0  full  good
# 21  below_average    0     0    0     0   bad
# 22            NaN    0     0    0     0  good
# 23       generous    0  half    0  full  good
# 24       generous    0     0    0     0  good
# 25  below_average    0  half  yes  full   bad
# 26  below_average  yes  none    0  half  good
# 27       generous    0     0  yes  full  good
# 28  below_average  yes  full  yes  full  good
# 29        average    0     0  yes  full   bad
# 30        average    0  half    0     0  good
# 31  below_average  yes  half  yes  full   bad
# 32        average    0     0    0     0   bad
# 33  below_average   no  none    0  none   bad
# 34  below_average   no  half  yes  full   bad
# 35        average  yes  none  yes  full   bad
# 36       generous   no  none   no  none   bad
# 37  below_average  yes  half    0  none   bad
# 38        average    0     0  yes  none   bad
# 39        average  yes  full  yes  half  good

# %% [markdown]
# In columns c2, c3 and c9, round the values to the nearest 0, 0.5 or 1. If any value is negative, then replace it with zero.

# %%
df[['c2', 'c3', 'c9']] = df[['c2', 'c3', 'c9']].applymap(lambda x: max(0, round(x * 2) / 2))

print(df)
# Out:
#     c1   c2   c3   c4    c5  c6          c7    c8    c9  c10  c11  \
# 0    1  5.0  0.0  0.0     0  40           0   0.0   2.0    0   11
# 1    2  4.5  6.0  0.0     0  35    ret_allw   0.0   0.0  yes   11
# 2    0  0.0  0.0  0.0     0  38  empl_contr   0.0   5.0    0   11
# 3    3  3.5  4.0  5.0    tc   0           0   0.0   0.0  yes    0
# 4    3  4.5  4.5  5.0     0  40           0   0.0   0.0    0   12
# 5    2  2.0  2.5  0.0     0  35           0   0.0   6.0  yes   12
# 6    3  4.0  5.0  5.0    tc   0  empl_contr   0.0   0.0    0   12
# 7    3  7.0  5.0  2.3     0  40           0   0.0   3.0    0   12
# 8    2  3.0  7.0  0.0     0  38           0  12.0  25.0  yes   11
# 9    1  5.5  0.0  0.0  none  40  empl_contr   0.0   4.0    0   11
# 10   3  3.5  4.0  4.6  none  36           0   0.0   3.0    0   13
# 11   2  6.5  6.5  0.0     0  38           0   0.0   4.0    0   15
# 12   2  3.5  4.0  0.0  none  40           0   0.0   2.0   no   10
# 13   3  3.5  4.0  5.1   tcf  37           0   0.0   4.0    0   13
# 14   1  3.0  0.0  0.0  none  36           0   0.0  10.0   no   11
# 15   2  4.5  4.0  0.0  none  37  empl_contr   0.0   0.0    0   11
# 16   1  3.0  0.0  0.0     0  35           0   0.0   2.0    0   12
# 17   1  2.0  0.0  0.0    tc  40    ret_allw   2.0   3.0   no    9
# 18   1  2.0  0.0  0.0  none  38        none   0.0   0.0  yes   11
# 19   2  4.0  5.0  0.0   tcf  35           0  13.0   5.0    0   15
# 20   2  4.5  4.5  0.0     0  38           0   0.0   4.0    0   12
# 21   2  2.5  3.0  0.0     0  40        none   0.0   0.0    0   11
# 22   3  3.5  4.0  4.6   tcf  27           0   0.0   0.0    0    0
# 23   2  4.5  4.0  0.0     0  40           0   0.0   4.0    0   10
# 24   1  6.0  0.0  0.0     0  38           0   8.0   3.0    0    9
# 25   3  2.0  2.0  2.0  none  40        none   0.0   0.0    0   10
# 26   2  4.5  4.5  0.0   tcf   0           0   0.0   0.0  yes   10
# 27   2  3.0  3.0  0.0  none  33           0   0.0   0.0  yes   12
# 28   2  5.0  4.0  0.0  none  37           0   0.0   5.0   no   11
# 29   3  2.0  2.5  0.0     0  35        none   0.0   0.0    0   10
# 30   3  4.5  4.5  5.0  none  40           0   0.0   0.0   no   11
# 31   3  3.0  2.0  2.5    tc  40        none   0.0   5.0   no   10
# 32   2  2.5  2.5  0.0     0  38  empl_contr   0.0   0.0    0   10
# 33   2  4.0  5.0  0.0  none  40        none   0.0   3.0   no   10
# 34   3  2.0  2.5  2.1    tc  40        none   2.0   1.0   no   10
# 35   2  2.0  2.0  0.0  none  40        none   0.0   0.0   no   11
# 36   1  2.0  0.0  0.0    tc  40    ret_allw   4.0   0.0   no   11
# 37   1  3.0  0.0  0.0  none  38  empl_contr   2.0   3.0   no    9
# 38   3  2.0  2.5  2.0     0  37  empl_contr   0.0   0.0    0   10
# 39   2  4.5  4.0  0.0  none  40           0   0.0   4.0    0   12
#
#               c12  c13   c14  c15   c16   c17
# 0         average    0     0  yes     0  good
# 1   below_average    0  full    0  full  good
# 2        generous  yes  half  yes  half  good
# 3             NaN    0     0  yes     0  good
# 4         average    0  half  yes  half  good
# 5         average    0     0    0     0  good
# 6        generous  yes  none  yes  half  good
# 7   below_average    0     0    0     0  good
# 8   below_average  yes  half  yes     0  good
# 9        generous  yes  full    0     0  good
# 10       generous    0     0  yes  full  good
# 11            NaN    0  full    0     0  good
# 12  below_average   no  half    0  half   bad
# 13       generous    0  full  yes  full  good
# 14       generous    0     0    0     0  good
# 15        average    0  full  yes     0  good
# 16  below_average    0     0    0     0  good
# 17  below_average  yes  half    0  none   bad
# 18        average   no  none   no  none   bad
# 19       generous    0     0    0     0  good
# 20       generous    0  full    0  full  good
# 21  below_average    0     0    0     0   bad
# 22            NaN    0     0    0     0  good
# 23       generous    0  half    0  full  good
# 24       generous    0     0    0     0  good
# 25  below_average    0  half  yes  full   bad
# 26  below_average  yes  none    0  half  good
# 27       generous    0     0  yes  full  good
# 28  below_average  yes  full  yes  full  good
# 29        average    0     0  yes  full   bad
# 30        average    0  half    0     0  good
# 31  below_average  yes  half  yes  full   bad
# 32        average    0     0    0     0   bad
# 33  below_average   no  none    0  none   bad
# 34  below_average   no  half  yes  full   bad
# 35        average  yes  none  yes  full   bad
# 36       generous   no  none   no  none   bad
# 37  below_average  yes  half    0  none   bad
# 38        average    0     0  yes  none   bad
# 39        average  yes  full  yes  half  good

# %% [markdown]
# Plot hist graph for c3 and c9

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.hist(df['c3'], bins=10, color='blue', edgecolor='black')
plt.title('Histogram of c3')
plt.xlabel('c3 values')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(df['c9'], bins=10, color='green', edgecolor='black')
plt.title('Histogram of c9')
plt.xlabel('c9 values')
plt.ylabel('Frequency')

plt.tight_layout()

# %% [markdown]
# Draw scatter plot for any 3 relevant columns in your dataframe

# %%
numeric_df = df.apply(pd.to_numeric, errors='coerce').dropna()

plt.figure(figsize=(8, 6))

plt.scatter(numeric_df['c4'], numeric_df['c5'], color='green', label='c4 vs c5')
plt.scatter(numeric_df['c7'], numeric_df['c8'], color='blue', label='c7 vs c8')
plt.scatter(numeric_df['c10'], numeric_df['c11'], color='red', label='c10 vs c11')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Relevant Columns')
plt.legend()
plt.grid(True)
plt.show()
