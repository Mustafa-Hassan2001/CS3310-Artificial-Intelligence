# %% [markdown]
# ## **Pandas**
#
# Pandas is an open source library that provides easy to use data structures and data analysis tools to be used within Python. It is the basis of many other libraries used, mainly for data manipulation purposes.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.
#
# Relevant data is very important in data science.
#
# We will start with the main data structure that is offered within pandas library.

# %% [markdown]
# **Intallation Pandas**

# %%
# !pip install pandas

# %% [markdown]
# **Importing Pandas**

# %%
import pandas as pd

# %% [markdown]
# ## **Data Frame**
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types.
#
# It can be considered as a relational table (with multiple indexed rows and/or labeled columns), or dictionary where each value is a list.

# %% [markdown]
# **Creating DataFrame**
#
# In order to create a data from, following things are typically needed:
#
# - Data in n-dimensional array format.
# - Optional column title/header.
# - Optional index titles.
# - Optional data type (only one data type is allowed, or it can infer from the data).
#
# A constructor is defined for such purpose.

# %%
# Create DF with Random n-D Array
# Data: random 3 columns 1000 rows numbers between 0 and 1.
# col_names: ['col 1', 'col 2', 'col 3']

import numpy as np # import numpy to use rand function.

df = pd.DataFrame(np.random.rand(1000,3),
                  columns=['col 1', 'col 2', 'col 3'])

display(df)
# Out:
#         col 1     col 2     col 3
# 0    0.390574  0.700241  0.001493
# 1    0.594156  0.740133  0.766927
# 2    0.970469  0.202808  0.294698
# 3    0.671086  0.749560  0.844350
# 4    0.152246  0.091360  0.729224
# ..        ...       ...       ...
# 995  0.516195  0.885882  0.773539
# 996  0.025041  0.599128  0.876921
# 997  0.727423  0.079298  0.317736
# 998  0.286451  0.178701  0.136340
# 999  0.316450  0.668302  0.357191
#
# [1000 rows x 3 columns]

# %%
# Create DF with Dictionary
# Data: three patients data of calories and duration since last checkup.

#create dictionary

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

print(type(data))
# Out:
# <class 'dict'>

# %%
data
# Out:
# {'calories': [420, 380, 390], 'duration': [50, 40, 45]}

# %%
dataframe = pd.DataFrame(data)
display(dataframe)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#1. Display the above data.
df = pd.read_csv('Basic-1.csv', delimiter=',')

# display data
display(df)
# Out:
#      Gender      Job Type Province
# 0         M   Pink-collar    Hejaz
# 1         M  White-collar  Central
# 2         M   Pink-collar    Hejaz
# 3         M   Pink-collar    Hejaz
# 4         M   Gold-collar  Eastern
# ...     ...           ...      ...
# 1273      M   Blue-collar  Central
# 1274      M   Pink-collar    Hejaz
# 1275      F   Blue-collar    Hejaz
# 1276      F  White-collar  Central
# 1277      F   Blue-collar  Eastern
#
# [1278 rows x 3 columns]

# %%
# For larger data, it will only display few rows. You may be interested in viewing the initial rows, or the last ones or randomly.

# head(n=5), displays the starting rows (default is 5).
# tail(n=5), displays the ending rows (default is 5).
# sample(n=1), displays random rows (can also be set to fraction of data, using keyword frac), has other parameters as well.

df.head()
# Out:
#   Gender      Job Type Province
# 0      M   Pink-collar    Hejaz
# 1      M  White-collar  Central
# 2      M   Pink-collar    Hejaz
# 3      M   Pink-collar    Hejaz
# 4      M   Gold-collar  Eastern

# %%
df.tail()
# Out:
#      Gender      Job Type Province
# 1273      M   Blue-collar  Central
# 1274      M   Pink-collar    Hejaz
# 1275      F   Blue-collar    Hejaz
# 1276      F  White-collar  Central
# 1277      F   Blue-collar  Eastern

# %%
df.sample(5)
# Out:
#      Gender      Job Type Province
# 708       M   Blue-collar  Central
# 633       M   Gold-collar  Central
# 1244      F   Blue-collar  Eastern
# 417       M  White-collar    Hejaz
# 893       M   Blue-collar  Central

# %%
# summary statistics for non-numeric columns is available by default only when all columns are non-numeric

display(df.describe())

# count - represents the number of non-null entries.
# unique -  represents the number of unique values.
# top - represents the most frequently occurring value.
# freq - represents the frequency of the most common value.
# Out:
#        Gender      Job Type Province
# count    1278          1278     1278
# unique      2             4        3
# top         M  White-collar  Central
# freq      875           568      531

# %%
# Create DF from XLSX
# Data: Basic-2.xlsx
# col_names: Column are simply labeled from c1...c17. There are 17 columns

# 1. Display the above data.
import pandas as pd

df = pd.read_excel('Basic-2.xlsx')

display(df)
#display(df.head())
# Out:
#      c1   c2   c3   c4    c5    c6          c7    c8    c9  c10   c11  \
# 0   1.0  5.0  NaN  NaN   NaN  40.0         NaN   NaN   2.0  NaN  11.0
# 1   2.0  4.5  5.8  NaN   NaN  35.0    ret_allw   NaN   NaN  yes  11.0
# 2   NaN  NaN  NaN  NaN   NaN  38.0  empl_contr   NaN   5.0  NaN  11.0
# 3   3.0  3.7  4.0  5.0    tc   NaN         NaN   NaN   NaN  yes   NaN
# 4   3.0  4.5  4.5  5.0   NaN  40.0         NaN   NaN   NaN  NaN  12.0
# 5   2.0  2.0  2.5  NaN   NaN  35.0         NaN   NaN   6.0  yes  12.0
# 6   3.0  4.0  5.0  5.0    tc   NaN  empl_contr   NaN   NaN  NaN  12.0
# 7   3.0  6.9  4.8  2.3   NaN  40.0         NaN   NaN   3.0  NaN  12.0
# 8   2.0  3.0  7.0  NaN   NaN  38.0         NaN  12.0  25.0  yes  11.0
# 9   1.0  5.7  NaN  NaN  none  40.0  empl_contr   NaN   4.0  NaN  11.0
# 10  3.0  3.5  4.0  4.6  none  36.0         NaN   NaN   3.0  NaN  13.0
# 11  2.0  6.4  6.4  NaN   NaN  38.0         NaN   NaN   4.0  NaN  15.0
# ...

# %%
# What about the statistics.

df.describe()
# Out:
#               c1         c2         c3         c4         c6         c8  \
# count  39.000000  39.000000  30.000000  12.000000  37.000000   7.000000
# mean    2.102564   3.620513   3.913333   3.766667  37.810811   6.142857
# std     0.753758   1.331438   1.280822   1.415070   2.716593   4.845223
# min     1.000000   2.000000   2.000000   2.000000  27.000000   2.000000
# 25%     2.000000   2.500000   2.625000   2.250000  37.000000   2.000000
# 50%     2.000000   3.500000   4.000000   4.600000  38.000000   4.000000
# 75%     3.000000   4.500000   4.500000   5.000000  40.000000  10.000000
# max     3.000000   6.900000   7.000000   5.100000  40.000000  13.000000
#
#               c9        c11
# count  24.000000  38.000000
# mean    4.583333  11.105263
# std     4.754098   1.371318
# min     0.000000   9.000000
# 25%     3.000000  10.000000
# 50%     4.000000  11.000000
# 75%     5.000000  12.000000
# max    25.000000  15.000000

# %%
df.describe(include='all') #There is a keyword argument include within describe that can be used to force describe to publish statistics for all columns,
# Out:
#                c1         c2         c3         c4    c5         c6    c7  \
# count   39.000000  39.000000  30.000000  12.000000    24  37.000000    18
# unique        NaN        NaN        NaN        NaN     3        NaN     3
# top           NaN        NaN        NaN        NaN  none        NaN  none
# freq          NaN        NaN        NaN        NaN    14        NaN     8
# mean     2.102564   3.620513   3.913333   3.766667   NaN  37.810811   NaN
# std      0.753758   1.331438   1.280822   1.415070   NaN   2.716593   NaN
# min      1.000000   2.000000   2.000000   2.000000   NaN  27.000000   NaN
# 25%      2.000000   2.500000   2.625000   2.250000   NaN  37.000000   NaN
# 50%      2.000000   3.500000   4.000000   4.600000   NaN  38.000000   NaN
# 75%      3.000000   4.500000   4.500000   5.000000   NaN  40.000000   NaN
# max      3.000000   6.900000   7.000000   5.100000   NaN  40.000000   NaN
#
#                c8         c9  c10        c11            c12  c13   c14  c15  \
# ...

# %%
# Show summary of non-numeric (object) columns
df.describe(include='object')
# Out:
#           c5    c7 c10            c12  c13   c14  c15   c16   c17
# count     24    18  18             37   16    25   20    24    40
# unique     3     3   2              3    2     3    2     3     2
# top     none  none  no  below average  yes  half  yes  full  good
# freq      14     8  11             14   11    11   18    12    26

# %%
df.describe(exclude='float64')
# Out:
#           c5    c7 c10            c12  c13   c14  c15   c16   c17
# count     24    18  18             37   16    25   20    24    40
# unique     3     3   2              3    2     3    2     3     2
# top     none  none  no  below average  yes  half  yes  full  good
# freq      14     8  11             14   11    11   18    12    26

# %%
# pandas also offers a method to get information about the dataframe, specifically,
# how many non-null elements in each column and what is the data type of each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   c1      39 non-null     float64
#  1   c2      39 non-null     float64
#  2   c3      30 non-null     float64
#  3   c4      12 non-null     float64
#  4   c5      24 non-null     object
#  5   c6      37 non-null     float64
#  6   c7      18 non-null     object
#  7   c8      7 non-null      float64
#  8   c9      24 non-null     float64
#  9   c10     18 non-null     object
#  10  c11     38 non-null     float64
#  11  c12     37 non-null     object
#  12  c13     16 non-null     object
#  13  c14     25 non-null     object
#  14  c15     20 non-null     object
#  15  c16     24 non-null     object
#  16  c17     40 non-null     object
# dtypes: float64(8), object(9)
# memory usage: 5.4+ KB

# %%
#IF dataset is in json formatted file then
# df=pd.read_json('name.json')

# %%
df = pd.read_csv('Basic-1.csv', delimiter=',') #Readinf Basic-1.csv file

# %% [markdown]
# **INDEXING METHOD**
#
# iloc and loc are both indexing methods used in pandas to access elements in a DataFrame.
#
#
# **iloc:**
# - Stands for "integer location".
# - Uses integer-based indexing to access elements.
# - It is primarily used when you want to access DataFrame elements by their integer position.
# - The syntax is df.iloc[row_index, column_index].
#
#
# **loc:**
# - Stands for "location".
# - Uses label-based indexing to access elements.
# - It is primarily used when you want to access DataFrame elements by their index labels or column names.
# - The syntax is df.loc[row_label, column_label].

# %%
# Accessing via .iloc
# Consider the dataset given in Basic-1.csv. Display second row, second column element.

print(df.iloc[1,1]) #simple indexing
# Out:
# White-collar

# %%
print(df.loc[1,'Job Type'])
# Out:
# White-collar

# %%
df.columns
# Out:
# Index(['Gender', 'Job Type', 'Province'], dtype='object')

# %%
df['Gender']
# Out:
# 0       M
# 1       M
# 2       M
# 3       M
# 4       M
#        ..
# 1273    M
# 1274    M
# 1275    F
# 1276    F
# 1277    F
# Name: Gender, Length: 1278, dtype: object

# %%
# Using the second format, i.e. square brackets, you can access multiple columns as long as you provide list of their labels in a comma separated list.

df[['Gender', 'Province']]
# Out:
#      Gender Province
# 0         M    Hejaz
# 1         M  Central
# 2         M    Hejaz
# 3         M    Hejaz
# 4         M  Eastern
# ...     ...      ...
# 1273      M  Central
# 1274      M    Hejaz
# 1275      F    Hejaz
# 1276      F  Central
# 1277      F  Eastern
#
# [1278 rows x 2 columns]

# %%
# However, in order to access some rows over single/multiple columns, we can use loc() and iloc() functions as before. The indices will indicate that we are attempting to access multiple rows and/or columns.

# Slicing via .loc
# Access and display first 10 rows from the Gender - Province (both inclusive)


display(df.loc[0:9,'Gender':'Province'])
# Out:
#   Gender      Job Type Province
# 0      M   Pink-collar    Hejaz
# 1      M  White-collar  Central
# 2      M   Pink-collar    Hejaz
# 3      M   Pink-collar    Hejaz
# 4      M   Gold-collar  Eastern
# 5      M  White-collar    Hejaz
# 6      M   Blue-collar  Eastern
# 7      M   Blue-collar  Central
# 8      M  White-collar  Eastern
# 9      F  White-collar    Hejaz

# %%
# Access and display first second, fifth and eighth row from the Gender and Job Type column.

display(df.loc[[0,1,4,7],['Gender','Job Type']]) #not adjacent
# Out:
#   Gender      Job Type
# 0      M   Pink-collar
# 1      M  White-collar
# 4      M   Gold-collar
# 7      M   Blue-collar

# %%
# Slicing via .iloc
# Same can be done using iloc (using positions instead of labels).

display(df.iloc[0:9,0:3]) #using position/rank of columns
# Out:
#   Gender      Job Type Province
# 0      M   Pink-collar    Hejaz
# 1      M  White-collar  Central
# 2      M   Pink-collar    Hejaz
# 3      M   Pink-collar    Hejaz
# 4      M   Gold-collar  Eastern
# 5      M  White-collar    Hejaz
# 6      M   Blue-collar  Eastern
# 7      M   Blue-collar  Central
# 8      M  White-collar  Eastern

# %%
#Access and display first second, fifth and eighth  row from the second and fifth column.
display(df.iloc[[0,1,4,7],[2,1]]) #not adjacent or in  sequence
# Out:
#   Province      Job Type
# 0    Hejaz   Pink-collar
# 1  Central  White-collar
# 4  Eastern   Gold-collar
# 7  Central   Blue-collar

# %%
print('Dataframe has following columns.\n',df.columns)
# Out:
# Dataframe has following columns.
#  Index(['Gender', 'Job Type', 'Province'], dtype='object')

# %%
print('Dataframe has following rows.\n',df.index)
# Out:
# Dataframe has following rows.
#  RangeIndex(start=0, stop=1278, step=1)

# %%
print('The shape of the dataframe is:',df.shape)
# Out:
# The shape of the dataframe is: (1278, 3)

# %%
print('Following is the data type of each column:\n',df.dtypes)
# Out:
# Following is the data type of each column:
#  Gender      object
# Job Type    object
# Province    object
# dtype: object

# %%
print (f'Dataframe has {df.ndim} dimensions.')
# Out:
# Dataframe has 2 dimensions.

# %%
print('Size of dataframe is: ',df.size)
# Out:
# Size of dataframe is:  3834

# %%
print('Data Frame is empty', df.empty)
# Out:
# Data Frame is empty False

# %%
print('Following is the numpy array representation of the dataframe:\n',df.values)
# Out:
# Following is the numpy array representation of the dataframe:
#  [['M' 'Pink-collar' 'Hejaz']
#  ['M' 'White-collar' 'Central']
#  ['M' 'Pink-collar' 'Hejaz']
#  ...
#  ['F' 'Blue-collar' 'Hejaz']
#  ['F' 'White-collar' 'Central']
#  ['F' 'Blue-collar' 'Eastern']]

# %%
data = pd.DataFrame([])

# %%
print('Data Frame is empty', data.empty)
# Out:
# Data Frame is empty True

# %%
print(f'The number of non-null rows for each column are:\n{df.count()}')  #count ignores nan-values
# Out:
# The number of non-null rows for each column are:
# Gender      1278
# Job Type    1278
# Province    1278
# dtype: int64

# %%
df.value_counts() #value with max count
# Out:
# Gender  Job Type      Province
# M       White-collar  Central     151
#                       Hejaz       133
#         Blue-collar   Central     121
#                       Hejaz       106
#         White-collar  Eastern      98
# F       White-collar  Central      80
#                       Hejaz        66
# M       Blue-collar   Eastern      64
#         Pink-collar   Central      58
# F       Blue-collar   Central      56
#         White-collar  Eastern      40
#         Blue-collar   Hejaz        38
# M       Pink-collar   Hejaz        36
# F       Blue-collar   Eastern      31
# M       Gold-collar   Eastern      29
#         Pink-collar   Eastern      29
#         Gold-collar   Central      28
# F       Pink-collar   Central      24
# M       Gold-collar   Hejaz        22
# F       Pink-collar   Eastern      17
#         Gold-collar   Hejaz        14
#                       Central      13
#         Pink-collar   Hejaz        12
#         Gold-collar   Eastern      12
# ...

# %%
df['Job Type'].value_counts()['Pink-collar'] #for specific column, how many times 'no; showed up.
# Out:
# 176

# %%
display(df.loc[df['Job Type'] == 'Pink-collar',:])
# Out:
#      Gender     Job Type Province
# 0         M  Pink-collar    Hejaz
# 2         M  Pink-collar    Hejaz
# 3         M  Pink-collar    Hejaz
# 23        F  Pink-collar    Hejaz
# 32        M  Pink-collar  Eastern
# ...     ...          ...      ...
# 1240      M  Pink-collar  Central
# 1253      M  Pink-collar  Central
# 1263      M  Pink-collar  Eastern
# 1270      M  Pink-collar    Hejaz
# 1274      M  Pink-collar    Hejaz
#
# [176 rows x 3 columns]

# %%
# Display all rows related to White-collar jobs in Eastern Province.

selected_rows = (df['Province']=='Eastern') & (df['Job Type']=='White-collar')

display(df.loc[selected_rows,:])
# Out:
#      Gender      Job Type Province
# 8         M  White-collar  Eastern
# 18        F  White-collar  Eastern
# 27        M  White-collar  Eastern
# 31        M  White-collar  Eastern
# 37        M  White-collar  Eastern
# ...     ...           ...      ...
# 1226      M  White-collar  Eastern
# 1232      M  White-collar  Eastern
# 1238      F  White-collar  Eastern
# 1241      M  White-collar  Eastern
# 1256      M  White-collar  Eastern
#
# [138 rows x 3 columns]

# %%
#selected_rows = (df['Job Type']=='White-collar') | (df['Job Type']=='Blue-collar')

selected_rows = df['Job Type'].isin(['White-collar','Blue-collar'])

display(df.loc[selected_rows,:])
# Out:
#      Gender      Job Type Province
# 1         M  White-collar  Central
# 5         M  White-collar    Hejaz
# 6         M   Blue-collar  Eastern
# 7         M   Blue-collar  Central
# 8         M  White-collar  Eastern
# ...     ...           ...      ...
# 1272      M  White-collar  Central
# 1273      M   Blue-collar  Central
# 1275      F   Blue-collar    Hejaz
# 1276      F  White-collar  Central
# 1277      F   Blue-collar  Eastern
#
# [984 rows x 3 columns]

# %%
df.head()
# Out:
#   Gender      Job Type Province
# 0      M   Pink-collar    Hejaz
# 1      M  White-collar  Central
# 2      M   Pink-collar    Hejaz
# 3      M   Pink-collar    Hejaz
# 4      M   Gold-collar  Eastern

# %%
df.sort_values(by=['Gender'], inplace=True)
display(df.head())
# Out:
#      Gender      Job Type Province
# 1277      F   Blue-collar  Eastern
# 453       F   Blue-collar  Central
# 451       F   Blue-collar  Central
# 448       F   Blue-collar  Central
# 976       F  White-collar    Hejaz

# %%
df
# Out:
#      Gender      Job Type Province
# 1277      F   Blue-collar  Eastern
# 453       F   Blue-collar  Central
# 451       F   Blue-collar  Central
# 448       F   Blue-collar  Central
# 976       F  White-collar    Hejaz
# ...     ...           ...      ...
# 520       M  White-collar    Hejaz
# 521       M  White-collar    Hejaz
# 523       M   Blue-collar  Central
# 476       M  White-collar  Eastern
# 638       M  White-collar    Hejaz
#
# [1278 rows x 3 columns]

# %%
# sort by single column in descending order
df.sort_values(by=['Province'], inplace=True, ascending=False)
display(df.head())
# Out:
#     Gender      Job Type Province
# 638      M  White-collar    Hejaz
# 299      M  White-collar    Hejaz
# 371      M   Pink-collar    Hejaz
# 375      M   Blue-collar    Hejaz
# 381      M  White-collar    Hejaz

# %%
# sort by multiple columns
df.sort_values(by=['Gender','Province'], inplace=True, ascending=[True, False])

# %%
df
# Out:
#      Gender      Job Type Province
# 1115      F  White-collar    Hejaz
# 20        F  White-collar    Hejaz
# 235       F  White-collar    Hejaz
# 23        F   Pink-collar    Hejaz
# 232       F  White-collar    Hejaz
# ...     ...           ...      ...
# 295       M   Blue-collar  Central
# 365       M   Blue-collar  Central
# 336       M   Blue-collar  Central
# 290       M   Gold-collar  Central
# 25        M   Blue-collar  Central
#
# [1278 rows x 3 columns]

# %%
random_values = np.random.random(len(df)) * 100

# Adding random values as new columns
df['Random_Column'] = random_values

# %%
random_values1 = np.random.random(len(df)) * 100
random_values2 = np.random.random(len(df)) * 100

# Adding random values as new columns
df['Random_Column1'] = random_values1
df['Random_Column2'] = random_values2

# %%
df
# Out:
#      Gender      Job Type Province  Random_Column  Random_Column1  \
# 1115      F  White-collar    Hejaz      16.834112       88.383732
# 20        F  White-collar    Hejaz      14.156334       58.667032
# 235       F  White-collar    Hejaz       8.088953       87.776043
# 23        F   Pink-collar    Hejaz       6.167730       16.582779
# 232       F  White-collar    Hejaz       7.309447       61.876490
# ...     ...           ...      ...            ...             ...
# 295       M   Blue-collar  Central      38.195485       25.337772
# 365       M   Blue-collar  Central      17.901988       55.752159
# 336       M   Blue-collar  Central      11.347214        3.289849
# 290       M   Gold-collar  Central      83.749458       41.379639
# 25        M   Blue-collar  Central      17.431100       45.284491
#
#       Random_Column2
# 1115       58.079811
# 20         91.953798
# 235        95.206274
# 23         54.994771
# 232        90.382415
# ...              ...
# ...

# %%
df['Random_Column_New']=df['Random_Column'].apply(lambda x: int(round(x)))

# %%
df
# Out:
#      Gender      Job Type Province  Random_Column  Random_Column1  \
# 1115      F  White-collar    Hejaz      16.834112       88.383732
# 20        F  White-collar    Hejaz      14.156334       58.667032
# 235       F  White-collar    Hejaz       8.088953       87.776043
# 23        F   Pink-collar    Hejaz       6.167730       16.582779
# 232       F  White-collar    Hejaz       7.309447       61.876490
# ...     ...           ...      ...            ...             ...
# 295       M   Blue-collar  Central      38.195485       25.337772
# 365       M   Blue-collar  Central      17.901988       55.752159
# 336       M   Blue-collar  Central      11.347214        3.289849
# 290       M   Gold-collar  Central      83.749458       41.379639
# 25        M   Blue-collar  Central      17.431100       45.284491
#
#       Random_Column2  Random_Column_New
# 1115       58.079811                 17
# 20         91.953798                 14
# 235        95.206274                  8
# ...

# %%
df[['Random_Column1', 'Random_Column2']] = df[['Random_Column1', 'Random_Column2']].applymap(lambda x: int(round(x)))

# %%
df
# Out:
#      Gender      Job Type Province  Random_Column  Random_Column1  \
# 1115      F  White-collar    Hejaz      16.834112              88
# 20        F  White-collar    Hejaz      14.156334              59
# 235       F  White-collar    Hejaz       8.088953              88
# 23        F   Pink-collar    Hejaz       6.167730              17
# 232       F  White-collar    Hejaz       7.309447              62
# ...     ...           ...      ...            ...             ...
# 295       M   Blue-collar  Central      38.195485              25
# 365       M   Blue-collar  Central      17.901988              56
# 336       M   Blue-collar  Central      11.347214               3
# 290       M   Gold-collar  Central      83.749458              41
# 25        M   Blue-collar  Central      17.431100              45
#
#       Random_Column2  Random_Column_New
# 1115              58                 17
# 20                92                 14
# 235               95                  8
# ...

# %%
df['Job Type']=df['Job Type'].apply(lambda x: x.replace('-','_'))

# %%
df
# Out:
#      Gender      Job Type Province  Random_Column  Random_Column1  \
# 1115      F  White_collar    Hejaz      16.834112              88
# 20        F  White_collar    Hejaz      14.156334              59
# 235       F  White_collar    Hejaz       8.088953              88
# 23        F   Pink_collar    Hejaz       6.167730              17
# 232       F  White_collar    Hejaz       7.309447              62
# ...     ...           ...      ...            ...             ...
# 295       M   Blue_collar  Central      38.195485              25
# 365       M   Blue_collar  Central      17.901988              56
# 336       M   Blue_collar  Central      11.347214               3
# 290       M   Gold_collar  Central      83.749458              41
# 25        M   Blue_collar  Central      17.431100              45
#
#       Random_Column2  Random_Column_New
# 1115              58                 17
# 20                92                 14
# 235               95                  8
# ...

# %%
def Custom_Remark(x):
  if x>=50 and x<=100:
    return "Good"
  else:
    return "Bad"

# %%
df[['Random_Column_New_Remarks','Random_Column1_Remarks']]=df[['Random_Column_New','Random_Column1']].applymap(Custom_Remark)

# %%
df
# Out:
#      Gender      Job Type Province  Random_Column  Random_Column1  \
# 1115      F  White_collar    Hejaz      16.834112              88
# 20        F  White_collar    Hejaz      14.156334              59
# 235       F  White_collar    Hejaz       8.088953              88
# 23        F   Pink_collar    Hejaz       6.167730              17
# 232       F  White_collar    Hejaz       7.309447              62
# ...     ...           ...      ...            ...             ...
# 295       M   Blue_collar  Central      38.195485              25
# 365       M   Blue_collar  Central      17.901988              56
# 336       M   Blue_collar  Central      11.347214               3
# 290       M   Gold_collar  Central      83.749458              41
# 25        M   Blue_collar  Central      17.431100              45
#
#       Random_Column2  Random_Column_New Random_Column_New_Remarks  \
# 1115              58                 17                       Bad
# ...

# %% [markdown]
# ## **matplotlib library**
# We mostly use pyplot interface of matplotlib library as it provides a MATLAB-style, procedural, state-machine interface to the underlying object-oriented library in Matplotlib. Pyplot is a collection of command style functions that make Matplotlib work like MATLAB. Each pyplot function makes some change to a figure - e.g., creates a figure, creates a plotting area in a figure etc.
#
# Matplotlib.pyplot is a collection of commands and functions that make Matplotlib behave like MATLAB (for plotting). The MATLAB-style tools are contained in the pyplot (plt) interface.

# %%
#Install

# !pip install matplotlib

# %%
# Import Matplotlib

import matplotlib.pyplot as plt

# %%
x1= np.linspace(0,10,100) #100 points linearly spaced between 0 and 10.
plt.plot(x1, np.sin(x1), '-')
plt.show()

# %%
plt.plot(x1, np.cos(x1), '--')
plt.show()

# %%
plt.plot(x1, np.sin(x1), '-')
plt.plot(x1, np.cos(x1), '--')

plt.show()

# %%
# If we want to create subplots within a figure and not multiple figures, we can divide figures into multiple subplots using the function subplot() within pyplot.

# subplot(nrows, ncols, index)
# divides the figure into nrows and ncols and index refers to which plot you want to access. There are many other arguments. So, for example, the function call subplot(2, 3, 1) which divide the figure into 2 rows and 3 columns (a total of 6 subplots) and the index==1 indicates that the next plot will be plotted in panel 1. (Here indexing starts from 1)

# create a plot figure
plt.figure()


# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.sin(x1))

plt.ylabel('Sine')


# create the second of two panels and set current axis
plt.subplot(212)   # (rows, columns, panel number)
#you can skip the commas and it still works.
plt.plot(x1, np.cos(x1));
plt.ylabel('Cosine')
# Out:
# Text(0, 0.5, 'Cosine')

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x,'r-',label='linear')
plt.plot(x, x**2,'g*', label='quadratic')
plt.plot(x, x**3, 'b^', label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %%
data = [[ 66386, 174296,  75131, 577908,  32015],
        [ 58230, 381139,  78045,  99308, 160454],
        [ 89135,  80552, 152558, 497981, 603535],
        [ 78415,  81858, 150656, 193263,  69638],
        [139361, 331509, 343164, 781380,  52269]]

columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail')

plt.bar(columns, data[0]) #plot the first row
# Out:
# <BarContainer object of 5 artists>

# %%
#plotting on multiple rows
plt.figure(figsize=(6,10)) #resizing the figure
for i in range(len(data)): # for the length of data
        # print(f'subplot at row {len(data)}, column {1}, panel {i+1}')
        plt.subplot(len(data),1,i+1) #for each subplot, out of
        plt.bar(columns,data[i])

# %%
plt.figure(figsize=(5,5))

plt.pie(data[0],labels=columns);

plt.show()

# %%
# plotting on multiple rows and columns
plt.figure(figsize=(10,10)) #resizing the figure
nrows=ncols=round(len(data)/2) +1
for i in range(len(data)): # for the length of data
        print(f'subplot at row {nrows}, column {ncols}, panel {i+1}')
        plt.subplot(nrows, ncols,i+1) #for each subplot, out of
        plt.pie(data[i],labels=columns)
# Out:
# Object `print(f'subplot at row 3, column 3, panel 1')` not found.
# Object `print(f'subplot at row 3, column 3, panel 2')` not found.
# Object `print(f'subplot at row 3, column 3, panel 3')` not found.
# Object `print(f'subplot at row 3, column 3, panel 4')` not found.
# Object `print(f'subplot at row 3, column 3, panel 5')` not found.

# %%
Score = [ 75,  81,  95,  85,  81,  82,  97,  89,  76, 100,  77,  79,  87, 87,  79,  75, 100,  82,  83,  98, 86, 87, 71, 78, 81]
#Score = np.array(Score)

#plt.figure(figsize=(3,8))
plt.boxplot(Score)
plt.title('Box Plot')
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %%
Score2 = [80, 88, 72, 91, 88, 67, 76, 89, 65, 92, 77, 85, 71, 91, 66, 84, 87, 68, 69, 94, 81, 83, 87, 75, 67]

plt.figure(figsize=(6,8))
plt.boxplot([Score,Score2])
plt.xticks([1,2],labels=['Score','Score2'])
plt.show()

# %%
# Read and display information the data.
import pandas as pd
df = pd.read_csv('Basic-3.csv')


df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Add a new column to dataframe that represents total score. The total score is sum of score of math, reading, and writing scores.

df['Total score']=df['math score']+df['reading score']+df['writing score']
df.describe()
# Out:
#        math score  reading score  writing score  Total score
# count  1000.00000    1000.000000    1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000
# std      15.16308      14.600192      15.195657    42.771978
# min       0.00000      17.000000      10.000000    27.000000
# 25%      57.00000      59.000000      57.750000   175.000000
# 50%      66.00000      70.000000      69.000000   205.000000
# 75%      77.00000      79.000000      79.000000   233.000000
# max     100.00000     100.000000     100.000000   300.000000

# %%
df.plot(kind='hist',subplots=True,layout=(1,4),figsize=(20,5))
# Out:
# array([[<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>]],
#       dtype=object)

# %%
df.hist(figsize=(20,5),layout=(1,4))
# Out:
# array([[<Axes: title={'center': 'math score'}>,
#         <Axes: title={'center': 'reading score'}>,
#         <Axes: title={'center': 'writing score'}>,
#         <Axes: title={'center': 'Total score'}>]], dtype=object)

# %%
# Identify non-numeric columns
obj_columns = df.select_dtypes('object').columns

plt.figure(figsize=(20,20)) #resizing the figure
# Plot for each identified column
nrows=ncols=round(len(obj_columns)/2) +1

for i in range(len(obj_columns)): # for the length of columns
        plt.subplot(nrows, ncols,i+1) #for each subplot, out of
        df[obj_columns[i]].value_counts().plot(kind='bar',title=obj_columns[i],rot=45)
plt.show()

# %%
# Draw pie-chart for the non-numeric columns
#identify non-numeric columns
obj_columns = df.select_dtypes('object').columns

plt.figure(figsize=(20,20)) #resizing the figure
# Plot for each identified column
nrows=ncols=round(len(obj_columns)/2) +1

for i in range(len(obj_columns)): # for the length of columns
        plt.subplot(nrows, ncols,i+1) #for each subplot, out of
        df[obj_columns[i]].value_counts().plot(kind='pie',title=obj_columns[i],rot=45)
plt.show()

# %%
df.boxplot(by='gender',figsize=(10,10))
plt.show()

# %%
# Draw scatter plots of columns math score, reading score and writing score w.r.t Total score. Set the markers transparency level (alpha) to 0.5.
fig =plt.figure(figsize=(10,8))

df.plot(kind='scatter', x='Total score', y='math score', color='red', label='math score', alpha=0.5)
df.plot(kind='scatter', x='Total score',y='reading score',color='blue',label='reading score', alpha=0.5)
df.plot(kind='scatter', x='Total score',y='writing score',color='green',label='writing score', alpha=0.5)
# Out:
# <Axes: xlabel='Total score', ylabel='writing score'>

# %%
from google.colab import drive
drive.mount('/content/drive/')


df = pd.read_csv("/content/drive/MyDrive/Data/Basic-3.csv")
df
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
# ...
